# %% [markdown]
# <a href="https://colab.research.google.com/github/MCarvajalR/BootcampTalentoTech/blob/main/experiencia/Red_neuronal_para_clasificacion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from sklearn.datasets import  make_classification
from sklearn.model_selection import train_test_split

#generar un conjunto de datos de clasificacion sintetico
X, y = make_classification(n_samples=100, n_features=5,n_classes=2)

# dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

#convertir las etiquetas en codificacion onehot
y_train_categorical = keras.utils.to_categorical(y_train)
y_test_categorical = keras.utils.to_categorical(y_test)

#cre4acion del modelo
#crear una instacia de un modelo secuencial de keras
model = keras.models.Sequential()

#Añadir una capa oculta con 10 neuronas y activacion ReLu
model.add(keras.layers.Dense(10, input_shape=(X_train.shape[1],),activation='relu'))

#Añadir una capa de salida con 2 neuronas(una para cada clase y activacion softmax
model.add(keras.layers.Dense(2, activation='softmax'))

#compilar el modelo
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

#entrenar del modelo
model.fit(X_train, y_train_categorical, epochs=10, batch_size=32, validation_data=(X_test, y_test_categorical))

#evaluar el modelo en el conjunto de ´prueba
loss,accuracy = model.evaluate(X_test,y_test_categorical)

print("Perdida en el conjunto de prueba: ", loss)
print("Exactitud en el conjunto de prueba: ", accuracy)
# Out:
# Epoch 1/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 129ms/step - accuracy: 0.4000 - loss: 0.9136 - val_accuracy: 0.4000 - val_loss: 0.7992
# Epoch 2/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.4000 - loss: 0.8943 - val_accuracy: 0.4000 - val_loss: 0.7839
# Epoch 3/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.4125 - loss: 0.8769 - val_accuracy: 0.4500 - val_loss: 0.7686
# Epoch 4/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.4250 - loss: 0.8592 - val_accuracy: 0.4500 - val_loss: 0.7534
# Epoch 5/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.4500 - loss: 0.8430 - val_accuracy: 0.5500 - val_loss: 0.7385
# Epoch 6/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.4625 - loss: 0.8265 - val_accuracy: 0.5500 - val_loss: 0.7239
# Epoch 7/10
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.4750 - loss: 0.8103 - val_accuracy: 0.5500 - val_loss: 0.7097
# Epoch 8/10
# ...
